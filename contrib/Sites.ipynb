# %%
import pandas as pd

# %%
import dateparser
import datetime

# %%
df = pd.read_csv("t.tsv", sep="\t", names=["t", "count"], parse_dates=["t"])

# %%
df
# Out:
#                              t  count
# 0    2020-11-27 10:37:07+01:00  28470
# 1    2020-11-27 01:09:34+01:00  28468
# 2    2020-11-26 14:17:32+01:00  28446
# 3    2020-11-26 14:13:09+01:00  28445
# 4    2020-11-26 14:06:11+01:00  28445
# ..                         ...    ...
# 137  2017-12-06 21:46:29+01:00   3353
# 138  2017-11-28 01:05:01+01:00   3336
# 139  2017-07-03 22:23:06+02:00   3683
# 140  2016-12-21 13:55:10+01:00   3297
# 141  2016-04-17 15:50:52+02:00   2980
#
# [142 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   t       142 non-null    object
#  1   count   142 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.3+ KB

# %%
df["t"] = pd.to_datetime(df["t"], utc=True).dt.date

# %%
df[df["t"] > datetime.date(year=2020, month=11, day=1)]
# Out:
#              t  count
# 0   2020-11-27  28470
# 1   2020-11-27  28468
# 2   2020-11-26  28446
# 3   2020-11-26  28445
# 4   2020-11-26  28445
# 5   2020-11-26  28443
# 6   2020-11-26  28441
# 7   2020-11-24  28432
# 8   2020-11-16  28391
# 9   2020-11-16  28357
# 10  2020-11-15  28284
# 11  2020-11-15  28283
# 12  2020-11-15  28282
# 13  2020-11-12  28277
# 14  2020-11-10  28275
# 15  2020-11-10  28274
# 16  2020-11-10  28273
# 17  2020-11-09  28267
# 18  2020-11-06  28247
# 19  2020-11-05  28241

# %%
df[df["t"] > datetime.date(year=2019, month=11, day=1)].plot(x="t", y="count", grid=True, figsize=(14, 6))
# Out:
# <AxesSubplot:xlabel='t'>

# %%
df
# Out:
#               t  count
# 0    2020-11-27  28470
# 1    2020-11-27  28468
# 2    2020-11-26  28446
# 3    2020-11-26  28445
# 4    2020-11-26  28445
# ..          ...    ...
# 137  2017-12-06   3353
# 138  2017-11-28   3336
# 139  2017-07-03   3683
# 140  2016-12-21   3297
# 141  2016-04-17   2980
#
# [142 rows x 2 columns]
